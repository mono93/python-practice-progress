# %% [markdown]
# ## Welcome to python notebook
# ### Day 1
#
# This is where we can write our notes

# %%
print("Monojit")
# Out:
# Monojit

# %%
for i in range(5):
    print(f"value {i+1}")
# Out:
# value 1
# value 2
# value 3
# value 4
# value 5
